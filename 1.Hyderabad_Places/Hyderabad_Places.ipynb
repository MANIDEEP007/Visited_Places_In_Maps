# %% [markdown]
# <a href="https://colab.research.google.com/github/MANIDEEP007/Visited_Places_In_Maps/blob/main/1.Hyderabad_Places/Hyderabad_Places.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Author : Manideep Paduchuri

'''
About folium
-------------------
Python 3rd party library
Used for Data visualization in Maps
Based on strenghts of leaflet.js library
'''

import folium as fol
import pandas as pd

#Create Map object pointing to Hyderabad with inital Zoom level as 4
map_obj = fol.Map(
              location = [17.3850,78.4867],
               zoom_start=10,
               min_zoom = 10,
               max_zoom = 14,
               )

#Create Faature group object
feat_grp = fol.FeatureGroup(name="Hyderabad Places")

#Read data from CSV using Pandas and store in data frame
states_data = pd.read_csv("Hyderabad_Places.csv")

#Store particular columns from Dataframe as series
names =  states_data['PLACE']
lat   =  states_data['LATITUDE']
long  =  states_data['LONGITUDE']

#Add each State / UT to feature group
for name_each, lat_each, long_each in zip(names,lat,long):
    feat_grp.add_child(
        fol.Marker(
            location = [lat_each,long_each], 
            popup    = name_each,
            icon     = fol.Icon(color="green"),
            )
        )

#Add feature group to map
map_obj.add_child(feat_grp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2fa8a9bb45b5deaa85a5e0b81faeccf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2fa8a9bb45b5deaa85a5e0b81faeccf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c2fa8a9bb45b5deaa85a5e0b81faeccf = L.map(
#                 &quot;map_c2fa8a9bb45b5deaa85a5e0b81faeccf&quot;,
#                 {
#                     center: [17.385, 78.4867],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e8092f5c3d7d4a3352060eb45767e7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c2fa8a9bb45b5deaa85a5e0b81faeccf);
#
#
#             var feature_group_dd9863a46b87907bf91fbad0fbfd3469 = L.featureGroup(
#                 {}
#             ).addTo(map_c2fa8a9bb45b5deaa85a5e0b81faeccf);
#
#
#             var marker_21fabbf1a1224ad8c5090c67c7e6f7bf = L.marker(
#                 [17.3586, 78.2988],
#                 {}
#             ).addTo(feature_group_dd9863a46b87907bf91fbad0fbfd3469);
#
#
#             var icon_e7b83c95774af9ceebe5c4c72aff0287 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_21fabbf1a1224ad8c5090c67c7e6f7bf.setIcon(icon_e7b83c95774af9ceebe5c4c72aff0287);
#
#
#         var popup_24aa432b8a8efb188b25e50ef3498ec1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eb8ddeb02120e33f625ec4a449550f0d = $(`&lt;div id=&quot;html_eb8ddeb02120e33f625ec4a449550f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chilkur Balaji Temple&lt;/div&gt;`)[0];
#             popup_24aa432b8a8efb188b25e50ef3498ec1.setContent(html_eb8ddeb02120e33f625ec4a449550f0d);
#
#
#         marker_21fabbf1a1224ad8c5090c67c7e6f7bf.bindPopup(popup_24aa432b8a8efb188b25e50ef3498ec1)
#         ;
#
#
#
#
#             var marker_c25ddadf315c2026988a8aaac0adc9c0 = L.marker(
#                 [17.4969, 78.3964],
#                 {}
#             ).addTo(feature_group_dd9863a46b87907bf91fbad0fbfd3469);
#
#
#             var icon_6d2ac10378bc551be5d34b8c3b8e72a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c25ddadf315c2026988a8aaac0adc9c0.setIcon(icon_6d2ac10378bc551be5d34b8c3b8e72a3);
#
#
#         var popup_5471c30722a5ab0b709f327f60b561e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a2bd7e76f99ba348c280a5ef749b48bf = $(`&lt;div id=&quot;html_a2bd7e76f99ba348c280a5ef749b48bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viswanath Theatre&lt;/div&gt;`)[0];
#             popup_5471c30722a5ab0b709f327f60b561e2.setContent(html_a2bd7e76f99ba348c280a5ef749b48bf);
#
#
#         marker_c25ddadf315c2026988a8aaac0adc9c0.bindPopup(popup_5471c30722a5ab0b709f327f60b561e2)
#         ;
#
#
#
#
#             var marker_f8c0464a3cc6016acfefd6630654c618 = L.marker(
#                 [17.413, 78.4657],
#                 {}
#             ).addTo(feature_group_dd9863a46b87907bf91fbad0fbfd3469);
#
#
#             var icon_00d47174ff54afbea9d1656082d49d01 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8c0464a3cc6016acfefd6630654c618.setIcon(icon_00d47174ff54afbea9d1656082d49d01);
#
#
#         var popup_6ee1d3353a5269aaa41703b620a6bac3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f9dfb2bd0260a302cde581a78480afaf = $(`&lt;div id=&quot;html_f9dfb2bd0260a302cde581a78480afaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prasads Multiplex&lt;/div&gt;`)[0];
#             popup_6ee1d3353a5269aaa41703b620a6bac3.setContent(html_f9dfb2bd0260a302cde581a78480afaf);
#
#
#         marker_f8c0464a3cc6016acfefd6630654c618.bindPopup(popup_6ee1d3353a5269aaa41703b620a6bac3)
#         ;
#
#
#
#
#             var marker_8b4941118135ef7e7c99da44a2ffec56 = L.marker(
#                 [17.446, 78.3637],
#                 {}
#             ).addTo(feature_group_dd9863a46b87907bf91fbad0fbfd3469);
#
#
#             var icon_89009648f259f1bc22f939906ff9ebf8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor
