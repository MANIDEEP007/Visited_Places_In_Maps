# %% [markdown]
# <a href="https://colab.research.google.com/github/MANIDEEP007/Visited_Places_In_Maps/blob/main/1.Hyderabad_Places/Hyderabad_Places.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Author : Manideep Paduchuri

'''
About folium
-------------------
Python 3rd party library
Used for Data visualization in Maps
Based on strenghts of leaflet.js library
'''

import folium as fol
import pandas as pd

#Create Map object pointing to Hyderabad with inital Zoom level as 4
map_obj = fol.Map(
              location = [17.3850,78.4867],
               zoom_start=10,
               min_zoom = 10,
               max_zoom = 14,
               )

#Create Faature group object
feat_grp = fol.FeatureGroup(name="Hyderabad Places")

#Read data from CSV using Pandas and store in data frame
states_data = pd.read_csv("Hyderabad_Places.csv")

#Store particular columns from Dataframe as series
names =  states_data['PLACE']
lat   =  states_data['LATITUDE']
long  =  states_data['LONGITUDE']

#Add each State / UT to feature group
for name_each, lat_each, long_each in zip(names,lat,long):
    feat_grp.add_child(
        fol.Marker(
            location = [lat_each,long_each], 
            popup    = name_each,
            icon     = fol.Icon(color="green"),
            )
        )

#Add feature group to map
map_obj.add_child(feat_grp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb6eb8a1badfa4e1c26f29c5345eddc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb6eb8a1badfa4e1c26f29c5345eddc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb6eb8a1badfa4e1c26f29c5345eddc3 = L.map(
#                 &quot;map_eb6eb8a1badfa4e1c26f29c5345eddc3&quot;,
#                 {
#                     center: [17.385, 78.4867],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1674f13ff7335f0510eb5579ba783acf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb6eb8a1badfa4e1c26f29c5345eddc3);
#
#
#             var feature_group_fc42c49f1e0a3f6423596d15fd1c91ee = L.featureGroup(
#                 {}
#             ).addTo(map_eb6eb8a1badfa4e1c26f29c5345eddc3);
#
#
#             var marker_bd512cdbb7f3c9320c72bcc932ae0ede = L.marker(
#                 [17.3586, 78.2988],
#                 {}
#             ).addTo(feature_group_fc42c49f1e0a3f6423596d15fd1c91ee);
#
#
#             var icon_706087452437899d8abb20b30f272664 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd512cdbb7f3c9320c72bcc932ae0ede.setIcon(icon_706087452437899d8abb20b30f272664);
#
#
#         var popup_8a7e7af66098cd60dcd8eb000fc82408 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_56f6b59e71365ba9e50c0361b44aa4fc = $(`&lt;div id=&quot;html_56f6b59e71365ba9e50c0361b44aa4fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chilkur Balaji Temple&lt;/div&gt;`)[0];
#             popup_8a7e7af66098cd60dcd8eb000fc82408.setContent(html_56f6b59e71365ba9e50c0361b44aa4fc);
#
#
#         marker_bd512cdbb7f3c9320c72bcc932ae0ede.bindPopup(popup_8a7e7af66098cd60dcd8eb000fc82408)
#         ;
#
#
#
#
#             var marker_f1dd62fcc55c36c2a879ee426252317e = L.marker(
#                 [17.4969, 78.3964],
#                 {}
#             ).addTo(feature_group_fc42c49f1e0a3f6423596d15fd1c91ee);
#
#
#             var icon_b297e681b6516a6486fe86a1b3f58c6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f1dd62fcc55c36c2a879ee426252317e.setIcon(icon_b297e681b6516a6486fe86a1b3f58c6b);
#
#
#         var popup_c6a263f11664e84e7957af69f76d8cc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ada323100cf74c73e31497da1831001 = $(`&lt;div id=&quot;html_6ada323100cf74c73e31497da1831001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viswanath Theatre&lt;/div&gt;`)[0];
#             popup_c6a263f11664e84e7957af69f76d8cc8.setContent(html_6ada323100cf74c73e31497da1831001);
#
#
#         marker_f1dd62fcc55c36c2a879ee426252317e.bindPopup(popup_c6a263f11664e84e7957af69f76d8cc8)
#         ;
#
#
#
#
#             var marker_2c955b5bc5b172999cc3c08ace6d2407 = L.marker(
#                 [17.413, 78.4657],
#                 {}
#             ).addTo(feature_group_fc42c49f1e0a3f6423596d15fd1c91ee);
#
#
#             var icon_f5f9dda0dfab38895c1a344c006f7c9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c955b5bc5b172999cc3c08ace6d2407.setIcon(icon_f5f9dda0dfab38895c1a344c006f7c9b);
#
#
#         var popup_a64ef024f28cf9aeb1321d0b9b3eab9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a87855c2e03a36371cb2614011e69cd5 = $(`&lt;div id=&quot;html_a87855c2e03a36371cb2614011e69cd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prasads Multiplex&lt;/div&gt;`)[0];
#             popup_a64ef024f28cf9aeb1321d0b9b3eab9d.setContent(html_a87855c2e03a36371cb2614011e69cd5);
#
#
#         marker_2c955b5bc5b172999cc3c08ace6d2407.bindPopup(popup_a64ef024f28cf9aeb1321d0b9b3eab9d)
#         ;
#
#
#
#
#             var marker_34e35ce232f2738a7fb8caa7ff881013 = L.marker(
#                 [17.446, 78.3637],
#                 {}
#             ).addTo(feature_group_fc42c49f1e0a3f6423596d15fd1c91ee);
#
#
#             var icon_eb3659cc1add97e4a1e29945006cd85b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,
